# %% [markdown]
# # Project 04 : Retail Analysis with Walmart Data

# %% [markdown]
# <hr style="border: solid rgb(255,255,255) 1.0px;height: 2.0px;"/>

# %% [markdown]
# ## <font color=blue>Basic Statistics tasks

# %% [markdown]
# •	Which store has maximum sales
#
# •	Which store has maximum standard deviation i.e., the sales vary a lot. Also, find out the coefficient of mean to standard deviation
#
# •	Which store/s has good quarterly growth rate in Q3’2012
#
# •	Some holidays have a negative impact on sales. Find out holidays which have higher sales than the mean sales in non-holiday season for all stores together
#
# •	Provide a monthly and semester view of sales in units and give insights

# %%
# importing the dataset
import pandas as pd
df_rawdata = pd.read_csv("S:\\SandeepG\\Official\\DataScience\\SimpliLearn\\Data Science with Python\\Projects\\Project 05 - Walmart\\Walmart_Store_sales.csv",  sep=',', engine='python', header='infer')
df_rawdata
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    5/2/2010    1643690.90             0        42.31       2.572
# 1         1   12/2/2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1    5/3/2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45   5/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %% [markdown]
# #### <font color=blue>Question : Which store has maximum sales?

# %%
# converting weekly_sales in millions term to interpret the number better
df_rawdata['Weekly_Sales_InMillions'] = df_rawdata['Weekly_Sales']/1000000

df_rawdata
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    5/2/2010    1643690.90             0        42.31       2.572
# 1         1   12/2/2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1    5/3/2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45   5/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Weekly_Sales_InMillions
# 0     211.096358         8.106                 1.643691
# 1     211.242170         8.106                 1.641957
# 2     211.289143         8.106                 1.611968
# 3     211.319643         8.106                 1.409728
# 4     211.350143         8.106                 1.554807
# ...          ...           ...                      ...
# 6430  192.013558         8.684                 0.713174
# 6431  192.170412         8.667                 0.733455
# 6432  192.327265         8.667                 0.734464
# 6433  192.330854         8.667                 0.718126
# 6434  192.308899         8.667                 0.760281
#
# [6435 rows x 9 columns]

# %%
df_rawdata.groupby(['Store']).sum().sort_values(by = 'Weekly_Sales_InMillions', ascending = False)
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_
# 1          1088.290               222.402809
# 39         1125.274               207.445542
# 19         1143.464               206.634862
# 31         1090.210               199.613905
# 23          685.830               198.750618
# 24         1207.923               194.016021
# 11         1026.309               193.962787
# 28         1875.657               189.263681
# 41          997.193               181.341935
# 32         1227.760               166.819246
# 18         1263.877               155.114734
# 22         1153.920               147.075649
# 12         1875.657               144.287230
# 26         1125.706               143.416394
# 34         1420.677               138.249763
# 40          685.830               137.870310
# 35         1256.766               131.520672
# 8           871.134               129.951181
# 17          936.565               127.782139
# 45         1236.771               112.395341
# 21         1090.210               108.117879
# 25         1054.112               101.061179
# 43         1420.677                90.565435
# 15         1143.464                89.133684
# 7          1227.760                81.598275
# 42         1195.904                79.565752
# 9           872.283                77.789219
# 29         1402.313                77.141554
# 16          926.353                74.252425
# 37         1125.274                74.202740
# 30         1090.210                62.716885
# 3          1026.309                57.586735
# 38         1875.657                55.159626
# 36         1125.274                53.412215
# 5           900.243                45.475689
# 44          963.194                43.293088
# 33         1220.241                37.160222

# %% [markdown]
# #### <font color=green>Answer : Store 20 has maximum sales

# %% [markdown]
# <hr style="border: solid rgb(255,255,255) 1.0px;height: 0.5px;"/>

# %% [markdown]
# #### <font color=blue> Question : Which store has maximum standard deviation i.e., the sales vary a lot. Also, find out the coefficient of mean to standard deviation?

# %%
import numpy as np

print(df_rawdata.groupby("Store") \
      .apply(np.std)[['Weekly_Sales_InMillions']]\
      .sort_values(by = 'Weekly_Sales_InMillions', ascending = False)\
      .head())
# Out:
#        Weekly_Sales_InMillions
# Store
# 14                    0.316458
# 10                    0.301203
# 20                    0.274934
# 4                     0.265269
# 13                    0.264577

# %% [markdown]
# #### <font color=green>Answer : Store 14 has maximum std deviation

# %%
# calculating mean and std
df_mean_std = df_rawdata.groupby(['Store'], as_index=False).agg({'Weekly_Sales_InMillions':['mean','std']})

# calculating coefficient of mean to std dev
df_mean_std['Weekly_Sales_InMillions', 'Cv'] = df_mean_std['Weekly_Sales_InMillions', 'std']/abs(df_mean_std['Weekly_Sales_InMillions', 'mean'])

# sort desc by std_dev
df_mean_std.sort_values([('Weekly_Sales_InMillions', 'std')], ascending=False).head(1)
# Out:
#    Store Weekly_Sales_InMillions
#                             mean      std        Cv
# 13    14                2.020978  0.31757  0.157137

# %% [markdown]
# #### <font color=green>Answer : Above displays store with max std_dev and its coefficient of mean to std_dev (Cv)

# %% [markdown]
# #### <font color=blue> Question : Which store/s has good quarterly growth rate in Q3’2012

# %% [markdown]
# <hr style="border: solid rgb(255,255,255) 1.0px;height: 2.0px;"/>
