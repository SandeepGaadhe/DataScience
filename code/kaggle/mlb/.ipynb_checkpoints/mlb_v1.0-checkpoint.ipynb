# %% [markdown]
# ### Load the dataset

# %%
import pandas as pd
import os
import matplotlib
import plotly.express as px

# %%
df_awards = pd.read_csv(r"S:\SandeepG\Official\DataScience\gitHub\data\kaggle\mlb\awards.csv")
df_players = pd.read_csv(r"S:\SandeepG\Official\DataScience\gitHub\data\kaggle\mlb\players.csv")
df_seasons = pd.read_csv(r"S:\SandeepG\Official\DataScience\gitHub\data\kaggle\mlb\seasons.csv")
df_teams = pd.read_csv(r"S:\SandeepG\Official\DataScience\gitHub\data\kaggle\mlb\teams.csv")

# %% [markdown]
# ### Following https://www.kaggle.com/miklgr500/mlb-player-digital-engagement-forecasting-eda

# %%
df_players.head()
# Out:
#    playerId          playerName         DOB mlbDebutDate            birthCity  \
# 0    665482  Gilberto Celestino  1999-02-13   2021-06-02        Santo Domingo
# 1    593590       Webster Rivas  1990-08-08   2021-05-28                Nagua
# 2    661269  Vladimir Gutierrez  1995-09-18   2021-05-28               Havana
# 3    669212          Eli Morgan  1996-05-13   2021-05-28  Rancho Palos Verdes
# 4    666201         Alek Manoah  1998-01-09   2021-05-27            Homestead
#
#   birthStateProvince        birthCountry  heightInches  weight  \
# 0                NaN  Dominican Republic            72     170
# 1                NaN  Dominican Republic            73     219
# 2                NaN                Cuba            73     190
# 3                 CA                 USA            70     190
# 4                 FL                 USA            78     260
#
#   primaryPositionCode primaryPositionName playerForTestSetAndFuturePreds
# 0                   8          Outfielder                          False
# 1                   3          First Base                           True
# 2                   1             Pitcher                           True
# 3                   1             Pitcher                           True
# 4                   1             Pitcher                           True

# %%
df_players.describe()
# Out:
#             playerId  heightInches       weight
# count    2061.000000   2061.000000  2061.000000
# mean   587590.916060     73.750607   210.942261
# std     71127.947793      2.309101    20.733118
# min    112526.000000     66.000000   151.000000
# 25%    543343.000000     72.000000   196.000000
# 50%    605388.000000     74.000000   210.000000
# 75%    642758.000000     75.000000   225.000000
# max    685503.000000     82.000000   300.000000

# %%
df_players['DOB'] = pd.to_datetime(df_players['DOB'])

# %%
df_players['DOB'].describe()
# Out:
# count                    2061
# unique                   1670
# top       1995-01-17 00:00:00
# freq                        5
# first     1973-05-24 00:00:00
# last      2000-05-16 00:00:00
# Name: DOB, dtype: object

# %%
df_players["DOB"].groupby(df_players["DOB"].dt.year).count().plot(kind="bar")

# %%
#df_players['densety'] = 1 / len(df_players)
#df_players = df_players.fillna('NaN')

#fig = px.sunburst(df_players, path=['playerForTestSetAndFuturePreds', 'primaryPositionName', 'birthCountry', 'birthStateProvince', 'birthCity'], values='densety')
fig = px.sunburst(df_players, path=['playerForTestSetAndFuturePreds', 'primaryPositionName', 'birthCountry', 'birthStateProvince'], values='densety')
fig.show()
# Out:
# <div>                            <div id="c628de60-7ffe-41b0-935e-cba20cb8d1cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c628de60-7ffe-41b0-935e-cba20cb8d1cc")) {                    Plotly.newPlot(                        "c628de60-7ffe-41b0-935e-cba20cb8d1cc",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>densety=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["False/Pitcher/Canada/AB", "False/Pitcher/USA/AK", "True/Catcher/USA/AL", "False/Outfielder/USA/AL", "True/Outfielder/USA/AL", "False/Pitcher/USA/AL", "True/Pitcher/USA/AL", "False/Second Base/USA/AL", "True/Shortstop/USA/AL", "False/Outfielder/USA/AR", "True/Outfielder/USA/AR", "False/Pitcher/USA/AR", "True/Pitcher/USA/AR", "False/Catcher/USA/AZ", "False/Outfielder/USA/AZ", "True/Outfielder/USA/AZ", "False/Pitcher/USA/AZ", "True/Pitcher/USA/AZ", "False/Second Base/USA/AZ", "True/Second Base/USA/AZ", "True/Shortstop/USA/AZ", "False/Third Base/USA/AZ", "False/Outfielder/Canada/BC", "True/Outfielder/Canada/BC", "False/Pitcher/Canada/BC", "True/Pitcher/Canada/BC", "True/Catcher/Mexico/Baja California", "False/Catcher/USA/CA", "True/Catcher/USA/CA", "False/Designated Hitter/USA/CA", "True/Designated Hitter/USA/CA", "False/First Base/USA/CA", "True/First Base/USA/CA", "NaN/First Base/USA/CA", "False/Outfield/USA/CA", "False/Outfielder/USA/CA", "True/Outfielder/USA/CA", "False/Pitcher/USA/CA", "True/Pitcher/USA/CA", "False/Second Base/USA/CA", "True/Second Base/USA/CA", "False/Shortstop/USA/CA", "True/Shortstop/USA/CA", "False/Third Base/USA/CA", "True/Third Base/USA/CA", "False/Pitcher/USA/CO", "True/Pitcher/USA/CO", "True/Second Base/USA/CO", "False/Third Base/USA/CO", "True/Catcher/USA/CT", "True/Outfield/USA/CT", "False/Outfielder/USA/CT", "True/Outfielder/USA/CT", "False/Pitcher/USA/CT", "True/Pitcher/USA/CT", "True/Third Base/USA/CT", "True/Pitcher/Mexico/Coahuila", "False/First Base/USA/DC", "False/Outfielder/USA/DC", "True/Pitcher/USA/DC", "True/First Base/USA/DE", "True/Outfielder/USA/DE", "True/Pitcher/USA/DE", "True/Third Base/USA/DE", "False/Pitcher/Mexico/Durango", "False/Catcher/USA/FL", "True/Catcher/USA/FL", "False/First Base/USA/FL", "True/First Base/USA/FL", "False/Outfield/USA/FL", "True/Outfield/USA/FL", "False/Outfielder/USA/FL", "True/Outfielder/USA/FL", "False/Pitcher/USA/FL", "True/Pitcher/USA/FL", "False/Second Base/USA/FL", "True/Second Base/USA/FL", "False/Shortstop/USA/FL", "True/Shortstop/USA/FL", "False/Third Base/USA/FL", "True/Third Base/USA/FL", "False/Catcher/USA/GA", "True/Catcher/USA/GA", "False/First Base/USA/GA", "True/First Base/USA/GA", "True/Outfield/USA/GA", "False/Outfielder/USA/GA", "True/Outfielder/USA/GA", "False/Pitcher/USA/GA", "True/Pitcher/USA/GA", "False/Second Base/USA/GA", "True/Second Base/USA/GA", "False/Shortstop/USA/GA", "True/Shortstop/USA/GA", "False/Third Base/USA/GA", "True/Third Base/USA/GA", "True/Pitcher/USA/GU", "True/Catcher/USA/HI", "True/Outfielder/USA/HI", "False/Pitcher/USA/HI", "True/Pitcher/USA/HI", "True/Second Base/USA/HI", "True/Shortstop/USA/HI", "True/Outfielder/USA/IA", "False/Pitcher/USA/IA", "True/Pitcher/USA/IA", "False/Pitcher/USA/ID", "True/Pitcher/USA/ID", "True/Catcher/USA/IL", "False/First Base/USA/IL", "True/First Base/USA/IL", "False/Outfield/USA/IL", "False/Outfielder/USA/IL", "True/Outfielder/USA/IL", "False/Pitcher/USA/IL", "True/Pitcher/USA/IL", "False/Second Base/USA/IL", "True/Second Base/USA/IL", "False/Shortstop/USA/IL", "True/Shortstop/USA/IL", "False/Catcher/USA/IN", "True/Catcher/USA/IN", "False/First Base/USA/IN", "True/Outfielder/USA/IN", "False/Pitcher/USA/IN", "True/Pitcher/USA/IN", "True/Second Base/USA/IN", "True/Third Base/USA/I ...

# %%
df_players.columns
# Out:
# Index(['playerId', 'playerName', 'DOB', 'mlbDebutDate', 'birthCity',
#        'birthStateProvince', 'birthCountry', 'heightInches', 'weight',
#        'primaryPositionCode', 'primaryPositionName',
#        'playerForTestSetAndFuturePreds', 'densety'],
#       dtype='object')
